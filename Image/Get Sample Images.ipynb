# %%
from pathlib import Path

import requests
s = Path("Samples")

# %%
Path(s,'festival.jpg').write_bytes(
    requests.get(
        "https://static.independent.co.uk/s3fs-public/thumbnails/image/2015/06/16/16/festival.jpg"
    ).content
)

# %%
Path(s,'smiling.jpg').write_bytes(
    requests.get(
        "https://www.jenningswire.com/wp-content/uploads/2013/11/Happy-Smiling-People.jpg"
    ).content
)

# %% [markdown]
# # cat

# %%
Path(s,'cat.jpg').write_bytes(
    requests.get(
        "http://res.freestockphotos.biz/pictures/17/17885-cat-close-up-pv.jpg"
    ).content
)
