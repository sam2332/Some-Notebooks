# %%
from pathlib import Path
from cryptography import x509
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives import hashes
from bs4 import BeautifulSoup
import requests
import csv
from datetime import datetime

# %%
extentions = [".pem"]
root_path = '/etc/ssl/certs'

# %%
blacklist_cert_list=[]

# %%
def loadBlacklistedSSls():
    CSV_URL="https://sslbl.abuse.ch/blacklist/sslblacklist.csv"

    download = requests.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    lines = decoded_content.splitlines()
    cr = csv.reader(lines, delimiter=',')
    my_list = list(cr)
    headers = None
    results = []
    for row in my_list:
        if len(row) == 3:
            if headers is None:
                headers = row
                headers[0]=headers[0].strip('#').strip()
                continue
            results.append(dict(zip(headers,row)))
    return results
blacklist_cert_list += loadBlacklistedSSls()
blacklist_cert_list[-1]
# Out:
# {'Listingdate': '2014-05-04 08:09:56',
#  'SHA1': 'b08a4939fb88f375a2757eaddc47b1fb8b554439',
#  'Listingreason': 'Shylock C&C'}

# %%
print("Please review the list and make sure you do not have any banned certs")
for item in Path(root_path).iterdir():
    if item.is_file():
        if item.suffix in extentions:
            cert = x509.load_pem_x509_certificate(item.read_bytes(), default_backend())
            sha1_hashbytes = cert.fingerprint(hashes.SHA1())
            sha1_spaces= " ".join([format(i,'02x') for i in sha1_hashbytes])
            sha1 = "".join([format(i,'02x') for i in sha1_hashbytes])
            sha256_hashbytes = cert.fingerprint(hashes.SHA256())
            sha256 = " ".join([format(i,'02x') for i in sha256_hashbytes])
            trusted = False
            for b in blacklist_cert_list:
                if 'SHA1' in b and b['SHA1'] == sha1:
                    print
                    print("###### BANNED CERT:",b['Listingreason']) 
                    print('Filename:',item.stem)
                    print('Issuer:',cert.issuer)
                    print('Subject:',cert.subject)
                    print('Expires After:',cert.not_valid_after)
                    print('SN:',cert.serial_number)
                    print(sha1)
                    print(sha256)
print('>finished')
# Out:
# Please review the list and make sure you do not have any banned certs
# >finished

# %%
trusted_ca_list = []

# %%
def loadVisaTrustedCAs():
    url = "https://developer.visa.com/pages/trusted_certifying_authorities"
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    table = soup.find('table')
    if table is None:
        raise Exception(f"Table missing please check: {url}")
    first = True
    results = []
    for row in table.find_all('tr'):
        if first:
            first = False
            continue
        tds = row.find_all('td')
        results.append({
            'CA':tds[0].text.strip(),
            'Root Certificate Types':tds[1].text.strip(),
            'SHA1-Thumbprint':tds[2].text.strip().strip('\u200e'),
            'src':"Visa"
        })
    return results
trusted_ca_list += loadVisaTrustedCAs()
trusted_ca_list[-1]
# Out:
# {'CA': 'Verisign',
#  'Root Certificate Types': 'VeriSign Universal Root Certification Authority',
#  'SHA1-Thumbprint': '36 79 ca 35 66 87 72 30 4d 30 a5 fb 87 3b 0f a7 7b b7 0d 54',
#  'src': 'Visa'}

# %%
def loadMicrosoftTrustedCAs():
    CSV_URL="https://ccadb-public.secure.force.com/microsoft/IncludedCACertificateReportForMSFTCSV"

    download = requests.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    lines = decoded_content.splitlines()
    cr = csv.reader(lines, delimiter=',')
    my_list = list(cr)
    headers = None
    results = []
    for row in my_list:
        
        if len(row) == 10:
            if headers is None:
                headers = row
                headers[0]=headers[0].strip('#').strip()
                continue
            data = dict(zip(headers,row))
            data['src']='Microsoft'
            results.append(data)
    return results
trusted_ca_list += loadMicrosoftTrustedCAs()
trusted_ca_list[-1]
# Out:
# {'CA Owner': 'Zetes',
#  'CA Common Name or Certificate Name': 'ZETES TSP ROOT CA 001',
#  'SHA-1 Fingerprint': '3753D295FC6D8BC39B375650BFFC821AED504E1A',
#  'SHA-256 Fingerprint': '016E1DCD5F78841BBEBBAE9DDEA08C8D7EC54E698E95BB778ECDD1E10D8BF4F9',
#  'Valid From [GMT]': '2016 May 20',
#  'Valid To [GMT]': '2036 May 20',
#  'Public Key Algorithm': 'RSA 4096 bits',
#  'Signature Hash Algorithm': 'SHA256WithRSA',
#  'Microsoft EKUs': 'Client Authentication;Document Signing;Secure Email;Time Stamping',
#  'Microsoft Status': 'Included',
#  'src': 'Microsoft'}

# %%
def loadAppleTrustedCAs():
    url="https://support.apple.com/en-us/HT212773#trusted"
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    table = soup.find('table')
    if table is None:
        raise Exception(f"Table missing please check: {url}")
    first = True
    results = []
    for row in table.find_all('tr'):
        if first:
            first = False
            continue
        tds = row.find_all('td')
        results.append({
            'CA':tds[0].text.strip(),
            'Root Certificate Types':tds[2].text.strip(),
            'SHA256-Thumbprint':tds[8].text.strip(),
            "SRC":"Apple"
        })
    return results
trusted_ca_list += loadAppleTrustedCAs()

# %%
print('Certs listed below are expired')
print()
today = datetime.now()
for item in Path(root_path).iterdir():
    if item.is_file():
        if item.suffix in extentions:
            cert = x509.load_pem_x509_certificate(item.read_bytes(), default_backend())
            
            if(cert.not_valid_after<today):
                print('Expired Cert', cert)
                print('Filename:',item.stem)
                print('Issuer:',cert.issuer)
                print('Subject:',cert.subject)
                print('Expires After:',cert.not_valid_after)
                print('SN:',cert.serial_number)
                print(sha1)
                print(sha256)
                print()
print('>finished')
# Out:
# Certs listed below are expired
#
# Expired Cert <Certificate(subject=<Name(OU=GlobalSign Root CA - R2,O=GlobalSign,CN=GlobalSign)>, ...)>
# Filename: GlobalSign_Root_CA_-_R2
# Issuer: <Name(OU=GlobalSign Root CA - R2,O=GlobalSign,CN=GlobalSign)>
# Subject: <Name(OU=GlobalSign Root CA - R2,O=GlobalSign,CN=GlobalSign)>
# Expires After: 2021-12-15 08:00:00
# SN: 4835703278459682885658125
# 0d44dd8c3c8c1a1a58756481e90f2e2affb3d26e
# 18 ce 6c fe 7b f1 4e 60 b2 e3 47 b8 df e8 68 cb 31 d0 2e bb 3a da 27 15 69 f5 03 43 b4 6d b3 a4
#
# Expired Cert <Certificate(subject=<Name(O=Cybertrust\, Inc,CN=Cybertrust Global Root)>, ...)>
# Filename: Cybertrust_Global_Root
# Issuer: <Name(O=Cybertrust\, Inc,CN=Cybertrust Global Root)>
# Subject: <Name(O=Cybertrust\, Inc,CN=Cybertrust Global Root)>
# Expires After: 2021-12-15 08:00:00
# SN: 4835703278459682877484360
# 0d44dd8c3c8c1a1a58756481e90f2e2affb3d26e
# 18 ce 6c fe 7b f1 4e 60 b2 e3 47 b8 df e8 68 cb 31 d0 2e bb 3a da 27 15 69 f5 03 43 b4 6d b3 a4
#
# >finished

# %%
print('Please verify any certs listed below')
print()
for item in Path(root_path).iterdir():
    if item.is_file():
        if item.suffix in extentions:
            cert = x509.load_pem_x509_certificate(item.read_bytes(), default_backend())
            sha1_hashbytes = cert.fingerprint(hashes.SHA1())
            sha1_spaces= " ".join([format(i,'02x') for i in sha1_hashbytes])
            sha1 = "".join([format(i,'02x') for i in sha1_hashbytes])
            sha256_hashbytes = cert.fingerprint(hashes.SHA256())
            sha256_spaces = " ".join([format(i,'02x') for i in sha256_hashbytes])
            sha256 = "".join([format(i,'02x') for i in sha256_hashbytes])
            trusted = False
            for t in trusted_ca_list:
                if'SHA1-Thumbprint' in t:
                    if t['SHA1-Thumbprint'] == sha1_spaces:
                        trusted = True
                        break
                    else:
                        issue=f"SHA1-Thumbprint {sha1_spaces} != {t['SHA1-Thumbprint']}"
                        break
                        
                if'SHA256-Thumbprint' in t:
                    if t['SHA256-Thumbprint'] == sha256_spaces:
                        trusted = True
                        break
                    else:
                        issue=f"SHA256-Thumbprint {sha256_spaces} != {t['SHA256-Thumbprint']}"
                        break
                        
                if 'SHA-1 Fingerprint' in t:
                    if t['SHA-1 Fingerprint'] == sha1.upper():
                        trusted = True
                        break
                    else:
                        issue=f"SHA-1 Fingerprint {sha1.upper()} != {t['SHA-1 Fingerprint']}"
                        break
                        
                if 'SHA-256 Fingerprint' in t:
                    if t['SHA-256 Fingerprint'] == sha256.upper():
                        trusted = True
                        break
                    else:
                        issue=f"SHA-256 Fingerprint {sha256.upper()} != {t['SHA-256 Fingerprint']}"
                        break
                        
                
            if trusted == False:
                print('Filename:',item.stem)
                print('Issuer:',cert.issuer)
                print('Subject:',cert.subject)
                print('Expires After:',cert.not_valid_after)
                print('SN:',cert.serial_number)
                print('Issue:',issue)
                print("Trust By", t['src'])
                print(sha1)
                print(sha256)
                print()
print('>finished')
# Out:
# Please verify any certs listed below
#
# Filename: QuoVadis_Root_CA_3
# Issuer: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 3)>
# Subject: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 3)>
# Expires After: 2031-11-24 19:06:44
# SN: 1478
# Issue: SHA1-Thumbprint 1f 49 14 f7 d8 74 95 1d dd ae 02 c0 be fd 3a 2d 82 75 51 85 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 1f4914f7d874951dddae02c0befd3a2d82755185
# 18f1fc7f205df8adddeb7fe007dd57e3af375a9c4d8d73546bf4f1fed1e18d35
#
# Filename: Certigna
# Issuer: <Name(C=FR,O=Dhimyotis,CN=Certigna)>
# Subject: <Name(C=FR,O=Dhimyotis,CN=Certigna)>
# Expires After: 2027-06-29 15:13:05
# SN: 18364802974209362175
# Issue: SHA1-Thumbprint b1 2e 13 63 45 86 a4 6f 1a b2 60 68 37 58 2d c4 ac fd 94 97 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b12e13634586a46f1ab2606837582dc4acfd9497
# e3b6a2db2ed7ce48842f7ac53241c7b71d54144bfb40c11f3f1d0b42f5eea12d
#
# Filename: DigiCert_Assured_ID_Root_G2
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Assured ID Root G2)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Assured ID Root G2)>
# Expires After: 2038-01-15 12:00:00
# SN: 15385348160840213938643033620894905419
# Issue: SHA1-Thumbprint a1 4b 48 d9 43 ee 0a 0e 40 90 4f 3c e0 a4 c0 91 93 51 5d 3f != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# a14b48d943ee0a0e40904f3ce0a4c09193515d3f
# 7d05ebb682339f8c9451ee094eebfefa7953a114edb2f44949452fab7d2fc185
#
# Filename: Network_Solutions_Certificate_Authority
# Issuer: <Name(C=US,O=Network Solutions L.L.C.,CN=Network Solutions Certificate Authority)>
# Subject: <Name(C=US,O=Network Solutions L.L.C.,CN=Network Solutions Certificate Authority)>
# Expires After: 2029-12-31 23:59:59
# SN: 116697915152937497490437556386812487904
# Issue: SHA1-Thumbprint 74 f8 a3 c3 ef e7 b3 90 06 4b 83 90 3c 21 64 60 20 e5 df ce != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 74f8a3c3efe7b390064b83903c21646020e5dfce
# 15f0ba00a3ac7af3ac884c072b1011a077bd77c097f40164b2f8598abd83860c
#
# Filename: AffirmTrust_Premium_ECC
# Issuer: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Premium ECC)>
# Subject: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Premium ECC)>
# Expires After: 2040-12-31 14:20:24
# SN: 8401224907861490260
# Issue: SHA1-Thumbprint b8 23 6b 00 2f 1d 16 86 53 01 55 6c 11 a4 37 ca eb ff c3 bb != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b8236b002f1d16865301556c11a437caebffc3bb
# bd71fdf6da97e4cf62d1647add2581b07d79adf8397eb4ecba9c5e8488821423
#
# Filename: SSL.com_Root_Certification_Authority_RSA
# Issuer: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com Root Certification Authority RSA)>
# Subject: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com Root Certification Authority RSA)>
# Expires After: 2041-02-12 17:39:39
# SN: 8875640296558310041
# Issue: SHA1-Thumbprint b7 ab 33 08 d1 ea 44 77 ba 14 80 12 5a 6f bd a9 36 49 0c bb != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b7ab3308d1ea4477ba1480125a6fbda936490cbb
# 85666a562ee0be5ce925c1d8890a6f76a87ec16d4d7d5f29ea7419cf20123b69
#
# Filename: QuoVadis_Root_CA_1_G3
# Issuer: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 1 G3)>
# Subject: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 1 G3)>
# Expires After: 2042-01-12 17:27:44
# SN: 687049649626669250736271037606554624078720034195
# Issue: SHA1-Thumbprint 1b 8e ea 57 96 29 1a c9 39 ea b8 0a 81 1a 73 73 c0 93 79 67 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 1b8eea5796291ac939eab80a811a7373c0937967
# 8a866fd1b276b57e578e921c65828a2bed58e9f2f288054134b7f1f4bfc9cc74
#
# Filename: Buypass_Class_2_Root_CA
# Issuer: <Name(C=NO,O=Buypass AS-983163327,CN=Buypass Class 2 Root CA)>
# Subject: <Name(C=NO,O=Buypass AS-983163327,CN=Buypass Class 2 Root CA)>
# Expires After: 2040-10-26 08:38:03
# SN: 2
# Issue: SHA1-Thumbprint 49 0a 75 74 de 87 0a 47 fe 58 ee f6 c7 6b eb c6 0b 12 40 99 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 490a7574de870a47fe58eef6c76bebc60b124099
# 9a114025197c5bb95d94e63d55cd43790847b646b23cdf11ada4a00eff15fb48
#
# Filename: CFCA_EV_ROOT
# Issuer: <Name(C=CN,O=China Financial Certification Authority,CN=CFCA EV ROOT)>
# Subject: <Name(C=CN,O=China Financial Certification Authority,CN=CFCA EV ROOT)>
# Expires After: 2029-12-31 03:07:01
# SN: 407555286
# Issue: SHA1-Thumbprint e2 b8 29 4b 55 84 ab 6b 58 c2 90 46 6c ac 3f b8 39 8f 84 83 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# e2b8294b5584ab6b58c290466cac3fb8398f8483
# 5cc3d78e4e1d5e45547a04e6873e64f90cf9536d1ccc2ef800f355c4c5fd70fd
#
# Filename: COMODO_RSA_Certification_Authority
# Issuer: <Name(C=GB,ST=Greater Manchester,L=Salford,O=COMODO CA Limited,CN=COMODO RSA Certification Authority)>
# Subject: <Name(C=GB,ST=Greater Manchester,L=Salford,O=COMODO CA Limited,CN=COMODO RSA Certification Authority)>
# Expires After: 2038-01-18 23:59:59
# SN: 101909084537582093308941363524873193117
# Issue: SHA1-Thumbprint af e5 d2 44 a8 d1 19 42 30 ff 47 9f e2 f8 97 bb cd 7a 8c b4 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# afe5d244a8d1194230ff479fe2f897bbcd7a8cb4
# 52f0e1c4e58ec629291b60317f074671b85d7ea80d5b07273463534b32b40234
#
# Filename: DigiCert_Trusted_Root_G4
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Trusted Root G4)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Trusted Root G4)>
# Expires After: 2038-01-15 12:00:00
# SN: 7451500558977370777930084869016614236
# Issue: SHA1-Thumbprint dd fb 16 cd 49 31 c9 73 a2 03 7d 3f c8 3a 4d 7d 77 5d 05 e4 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ddfb16cd4931c973a2037d3fc83a4d7d775d05e4
# 552f7bdcf1a7af9e6ce672017f4f12abf77240c78e761ac203d1d9d20ac89988
#
# Filename: Security_Communication_Root_CA
# Issuer: <Name(C=JP,O=SECOM Trust.net,OU=Security Communication RootCA1)>
# Subject: <Name(C=JP,O=SECOM Trust.net,OU=Security Communication RootCA1)>
# Expires After: 2023-09-30 04:20:49
# SN: 0
# Issue: SHA1-Thumbprint 36 b1 2b 49 f9 81 9e d7 4c 9e bc 38 0f c6 56 8f 5d ac b2 f7 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 36b12b49f9819ed74c9ebc380fc6568f5dacb2f7
# e75e72ed9f560eec6eb4800073a43fc3ad19195a392282017895974a99026b6c
#
# Filename: TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1
# Issuer: <Name(C=TR,L=Gebze - Kocaeli,O=Turkiye Bilimsel ve Teknolojik Arastirma Kurumu - TUBITAK,OU=Kamu Sertifikasyon Merkezi - Kamu SM,CN=TUBITAK Kamu SM SSL Kok Sertifikasi - Surum 1)>
# Subject: <Name(C=TR,L=Gebze - Kocaeli,O=Turkiye Bilimsel ve Teknolojik Arastirma Kurumu - TUBITAK,OU=Kamu Sertifikasyon Merkezi - Kamu SM,CN=TUBITAK Kamu SM SSL Kok Sertifikasi - Surum 1)>
# Expires After: 2043-10-25 08:25:55
# SN: 1
# Issue: SHA1-Thumbprint 31 43 64 9b ec ce 27 ec ed 3a 3f 0b 8f 0d e4 e8 91 dd ee ca != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 3143649becce27eced3a3f0b8f0de4e891ddeeca
# 46edc3689046d53a453fb3104ab80dcaec658b2660ea1629dd7e867990648716
#
# Filename: SSL.com_Root_Certification_Authority_ECC
# Issuer: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com Root Certification Authority ECC)>
# Subject: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com Root Certification Authority ECC)>
# Expires After: 2041-02-12 18:14:03
# SN: 8495723813297216424
# Issue: SHA1-Thumbprint c3 19 7c 39 24 e6 54 af 1b c4 ab 20 95 7a e2 c3 0e 13 02 6a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# c3197c3924e654af1bc4ab20957ae2c30e13026a
# 3417bb06cc6007da1b961c920b8ab4ce3fad820e4aa30b9acbc4a74ebdcebc65
#
# Filename: Trustwave_Global_ECC_P256_Certification_Authority
# Issuer: <Name(C=US,ST=Illinois,L=Chicago,O=Trustwave Holdings\, Inc.,CN=Trustwave Global ECC P256 Certification Authority)>
# Subject: <Name(C=US,ST=Illinois,L=Chicago,O=Trustwave Holdings\, Inc.,CN=Trustwave Global ECC P256 Certification Authority)>
# Expires After: 2042-08-23 19:35:10
# SN: 4151900041497450638097112925
# Issue: SHA1-Thumbprint b4 90 82 dd 45 0c be 8b 5b b1 66 d3 e2 a4 08 26 cd ed 42 cf != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b49082dd450cbe8b5bb166d3e2a40826cded42cf
# 945bbc825ea554f489d1fd51a73ddf2ea624ac7019a05205225c22a78ccfa8b4
#
# Filename: D-TRUST_Root_Class_3_CA_2_2009
# Issuer: <Name(C=DE,O=D-Trust GmbH,CN=D-TRUST Root Class 3 CA 2 2009)>
# Subject: <Name(C=DE,O=D-Trust GmbH,CN=D-TRUST Root Class 3 CA 2 2009)>
# Expires After: 2029-11-05 08:35:58
# SN: 623603
# Issue: SHA1-Thumbprint 58 e8 ab b0 36 15 33 fb 80 f7 9b 1b 6d 29 d3 ff 8d 5f 00 f0 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 58e8abb0361533fb80f79b1b6d29d3ff8d5f00f0
# 49e7a442acf0ea6287050054b52564b650e4f49e42e348d6aa38e039e957b1c1
#
# Filename: certSIGN_Root_CA_G2
# Issuer: <Name(C=RO,O=CERTSIGN SA,OU=certSIGN ROOT CA G2)>
# Subject: <Name(C=RO,O=CERTSIGN SA,OU=certSIGN ROOT CA G2)>
# Expires After: 2042-02-06 09:27:35
# SN: 313609486401300475190
# Issue: SHA1-Thumbprint 26 f9 93 b4 ed 3d 28 27 b0 b9 4b a7 e9 15 1d a3 8d 92 e5 32 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 26f993b4ed3d2827b0b94ba7e9151da38d92e532
# 657cfe2fa73faa38462571f332a2363a46fce7020951710702cdfbb6eeda3305
#
# Filename: GTS_Root_R2
# Issuer: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R2)>
# Subject: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R2)>
# Expires After: 2036-06-22 00:00:00
# SN: 146587176055767053814479386953112547951
# Issue: SHA1-Thumbprint d2 73 96 2a 2a 5e 39 9f 73 3f e1 c7 1e 64 3f 03 38 34 fc 4d != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d273962a2a5e399f733fe1c71e643f033834fc4d
# c45d7bb08e6d67e62e4235110b564e5f78fd92ef058c840aea4e6455d7585c60
#
# Filename: GTS_Root_R3
# Issuer: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R3)>
# Subject: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R3)>
# Expires After: 2036-06-22 00:00:00
# SN: 146587176140553309517047991083707763997
# Issue: SHA1-Thumbprint 30 d4 24 6f 07 ff db 91 89 8a 0b e9 49 66 11 eb 8c 5e 46 e5 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 30d4246f07ffdb91898a0be9496611eb8c5e46e5
# 15d5b8774619ea7d54ce1ca6d0b0c403e037a917f131e8a04e1e6b7a71babce5
#
# Filename: GDCA_TrustAUTH_R5_ROOT
# Issuer: <Name(C=CN,O=GUANG DONG CERTIFICATE AUTHORITY CO.\,LTD.,CN=GDCA TrustAUTH R5 ROOT)>
# Subject: <Name(C=CN,O=GUANG DONG CERTIFICATE AUTHORITY CO.\,LTD.,CN=GDCA TrustAUTH R5 ROOT)>
# Expires After: 2040-12-31 15:59:59
# SN: 9009899650740120186
# Issue: SHA1-Thumbprint 0f 36 38 5b 81 1a 25 c3 9b 31 4e 83 ca e9 34 66 70 cc 74 b4 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 0f36385b811a25c39b314e83cae9346670cc74b4
# bfff8fd04433487d6a8aa60c1a29767a9fc2bbb05e420f713a13b992891d3893
#
# Filename: Certum_Trusted_Root_CA
# Issuer: <Name(C=PL,O=Asseco Data Systems S.A.,OU=Certum Certification Authority,CN=Certum Trusted Root CA)>
# Subject: <Name(C=PL,O=Asseco Data Systems S.A.,OU=Certum Certification Authority,CN=Certum Trusted Root CA)>
# Expires After: 2043-03-16 12:10:13
# SN: 40870380103424195783807378461123655149
# Issue: SHA1-Thumbprint c8 83 44 c0 18 ae 9f cc f1 87 b7 8f 22 d1 c5 d7 45 84 ba e5 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# c88344c018ae9fccf187b78f22d1c5d74584bae5
# fe7696573855773e37a95e7ad4d9cc96c30157c15d31765ba9b15704e1ae78fd
#
# Filename: Amazon_Root_CA_4
# Issuer: <Name(C=US,O=Amazon,CN=Amazon Root CA 4)>
# Subject: <Name(C=US,O=Amazon,CN=Amazon Root CA 4)>
# Expires After: 2040-05-26 00:00:00
# SN: 143266989758080763974105200630763877849284878
# Issue: SHA1-Thumbprint f6 10 84 07 d6 f8 bb 67 98 0c c2 e2 44 c2 eb ae 1c ef 63 be != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# f6108407d6f8bb67980cc2e244c2ebae1cef63be
# e35d28419ed02025cfa69038cd623962458da5c695fbdea3c22b0bfb25897092
#
# Filename: USERTrust_RSA_Certification_Authority
# Issuer: <Name(C=US,ST=New Jersey,L=Jersey City,O=The USERTRUST Network,CN=USERTrust RSA Certification Authority)>
# Subject: <Name(C=US,ST=New Jersey,L=Jersey City,O=The USERTRUST Network,CN=USERTrust RSA Certification Authority)>
# Expires After: 2038-01-18 23:59:59
# SN: 2645093764781058787591871645665788717
# Issue: SHA1-Thumbprint 2b 8f 1b 57 33 0d bb a2 d0 7a 6c 51 f7 0e e9 0d da b9 ad 8e != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2b8f1b57330dbba2d07a6c51f70ee90ddab9ad8e
# e793c9b02fd8aa13e21c31228accb08119643b749c898964b1746d46c3d4cbd2
#
# Filename: Entrust_Root_Certification_Authority_-_G4
# Issuer: <Name(C=US,O=Entrust\, Inc.,OU=See www.entrust.net/legal-terms,OU=(c) 2015 Entrust\, Inc. - for authorized use only,CN=Entrust Root Certification Authority - G4)>
# Subject: <Name(C=US,O=Entrust\, Inc.,OU=See www.entrust.net/legal-terms,OU=(c) 2015 Entrust\, Inc. - for authorized use only,CN=Entrust Root Certification Authority - G4)>
# Expires After: 2037-12-27 11:41:16
# SN: 289383649854506086828220374796556676440
# Issue: SHA1-Thumbprint 14 88 4e 86 26 37 b0 26 af 59 62 5c 40 77 ec 35 29 ba 96 01 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 14884e862637b026af59625c4077ec3529ba9601
# db3517d1f6732a2d5ab97c533ec70779ee3270a62fb4ac4238372460e6f01e88
#
# Filename: TWCA_Global_Root_CA
# Issuer: <Name(C=TW,O=TAIWAN-CA,OU=Root CA,CN=TWCA Global Root CA)>
# Subject: <Name(C=TW,O=TAIWAN-CA,OU=Root CA,CN=TWCA Global Root CA)>
# Expires After: 2030-12-31 15:59:59
# SN: 3262
# Issue: SHA1-Thumbprint 9c bb 48 53 f6 a4 f6 d3 52 a4 e8 32 52 55 60 13 f5 ad af 65 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 9cbb4853f6a4f6d352a4e83252556013f5adaf65
# 59769007f7685d0fcd50872f9f95d5755a5b2b457d81f3692b610a98672f0e1b
#
# Filename: TrustCor_RootCert_CA-2
# Issuer: <Name(C=PA,ST=Panama,L=Panama City,O=TrustCor Systems S. de R.L.,OU=TrustCor Certificate Authority,CN=TrustCor RootCert CA-2)>
# Subject: <Name(C=PA,ST=Panama,L=Panama City,O=TrustCor Systems S. de R.L.,OU=TrustCor Certificate Authority,CN=TrustCor RootCert CA-2)>
# Expires After: 2034-12-31 17:26:39
# SN: 2711694510199101698
# Issue: SHA1-Thumbprint b8 be 6d cb 56 f1 55 b9 63 d4 12 ca 4e 06 34 c7 94 b2 1c c0 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b8be6dcb56f155b963d412ca4e0634c794b21cc0
# 0753e940378c1bd5e3836e395daea5cb839e5046f1bd0eae1951cf10fec7c965
#
# Filename: Atos_TrustedRoot_2011
# Issuer: <Name(CN=Atos TrustedRoot 2011,O=Atos,C=DE)>
# Subject: <Name(CN=Atos TrustedRoot 2011,O=Atos,C=DE)>
# Expires After: 2030-12-31 23:59:59
# SN: 6643877497813316402
# Issue: SHA1-Thumbprint 2b b1 f5 3e 55 0c 1d c5 f1 d4 e6 b7 6a 46 4b 55 06 02 ac 21 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2bb1f53e550c1dc5f1d4e6b76a464b550602ac21
# f356bea244b7a91eb35d53ca9ad7864ace018e2d35d5f8f96ddf68a6f41aa474
#
# Filename: GlobalSign_Root_R46
# Issuer: <Name(C=BE,O=GlobalSign nv-sa,CN=GlobalSign Root R46)>
# Subject: <Name(C=BE,O=GlobalSign nv-sa,CN=GlobalSign Root R46)>
# Expires After: 2046-03-20 00:00:00
# SN: 1552617688466950547958867513931858518042577
# Issue: SHA1-Thumbprint 53 a2 b0 4b ca 6b d6 45 e6 39 8a 8e c4 0d d2 bf 77 c3 a2 90 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 53a2b04bca6bd645e6398a8ec40dd2bf77c3a290
# 4fa3126d8d3a11d1c4855a4f807cbad6cf919d3a5a88b03bea2c6372d93c40c9
#
# Filename: Entrust_Root_Certification_Authority
# Issuer: <Name(C=US,O=Entrust\, Inc.,OU=www.entrust.net/CPS is incorporated by reference,OU=(c) 2006 Entrust\, Inc.,CN=Entrust Root Certification Authority)>
# Subject: <Name(C=US,O=Entrust\, Inc.,OU=www.entrust.net/CPS is incorporated by reference,OU=(c) 2006 Entrust\, Inc.,CN=Entrust Root Certification Authority)>
# Expires After: 2026-11-27 20:53:42
# SN: 1164660820
# Issue: SHA1-Thumbprint b3 1e b1 b7 40 e3 6c 84 02 da dc 37 d4 4d f5 d4 67 49 52 f9 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b31eb1b740e36c8402dadc37d44df5d4674952f9
# 73c176434f1bc6d5adf45b0e76e727287c8de57616c1e6e6141a2b2cbc7d8e4c
#
# Filename: Go_Daddy_Class_2_CA
# Issuer: <Name(C=US,O=The Go Daddy Group\, Inc.,OU=Go Daddy Class 2 Certification Authority)>
# Subject: <Name(C=US,O=The Go Daddy Group\, Inc.,OU=Go Daddy Class 2 Certification Authority)>
# Expires After: 2034-06-29 17:06:20
# SN: 0
# Issue: SHA1-Thumbprint 27 96 ba e6 3f 18 01 e2 77 26 1b a0 d7 77 70 02 8f 20 ee e4 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2796bae63f1801e277261ba0d77770028f20eee4
# c3846bf24b9e93ca64274c0ec67c1ecc5e024ffcacd2d74019350e81fe546ae4
#
# Filename: GlobalSign_Root_CA_-_R3
# Issuer: <Name(OU=GlobalSign Root CA - R3,O=GlobalSign,CN=GlobalSign)>
# Subject: <Name(OU=GlobalSign Root CA - R3,O=GlobalSign,CN=GlobalSign)>
# Expires After: 2029-03-18 10:00:00
# SN: 4835703278459759426209954
# Issue: SHA1-Thumbprint d6 9b 56 11 48 f0 1c 77 c5 45 78 c1 09 26 df 5b 85 69 76 ad != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d69b561148f01c77c54578c10926df5b856976ad
# cbb522d7b7f127ad6a0113865bdf1cd4102e7d0759af635a7cf4720dc963c53b
#
# Filename: GlobalSign_Root_CA
# Issuer: <Name(C=BE,O=GlobalSign nv-sa,OU=Root CA,CN=GlobalSign Root CA)>
# Subject: <Name(C=BE,O=GlobalSign nv-sa,OU=Root CA,CN=GlobalSign Root CA)>
# Expires After: 2028-01-28 12:00:00
# SN: 4835703278459707669005204
# Issue: SHA1-Thumbprint b1 bc 96 8b d4 f4 9d 62 2a a8 9a 81 f2 15 01 52 a4 1d 82 9c != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b1bc968bd4f49d622aa89a81f2150152a41d829c
# ebd41040e4bb3ec742c9e381d31ef2a41a48b6685c96e7cef3c1df6cd4331c99
#
# Filename: GLOBALTRUST_2020
# Issuer: <Name(C=AT,O=e-commerce monitoring GmbH,CN=GLOBALTRUST 2020)>
# Subject: <Name(C=AT,O=e-commerce monitoring GmbH,CN=GLOBALTRUST 2020)>
# Expires After: 2040-06-10 00:00:00
# SN: 109160994242082918454945253
# Issue: SHA1-Thumbprint d0 67 c1 13 51 01 0c aa d0 c7 6a 65 37 31 16 26 4f 53 71 a2 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d067c11351010caad0c76a65373116264f5371a2
# 9a296a5182d1d451a2e37f439b74daafa267523329f90f9a0d2007c334e23c9a
#
# Filename: Izenpe.com
# Issuer: <Name(C=ES,O=IZENPE S.A.,CN=Izenpe.com)>
# Subject: <Name(C=ES,O=IZENPE S.A.,CN=Izenpe.com)>
# Expires After: 2037-12-13 08:27:25
# SN: 917563065490389241595536686991402621
# Issue: SHA1-Thumbprint 2f 78 3d 25 52 18 a7 4a 65 39 71 b5 2c a2 9c 45 15 6f e9 19 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2f783d255218a74a653971b52ca29c45156fe919
# 2530cc8e98321502bad96f9b1fba1b099e2d299e0f4548bb914f363bc0d4531f
#
# Filename: T-TeleSec_GlobalRoot_Class_2
# Issuer: <Name(C=DE,O=T-Systems Enterprise Services GmbH,OU=T-Systems Trust Center,CN=T-TeleSec GlobalRoot Class 2)>
# Subject: <Name(C=DE,O=T-Systems Enterprise Services GmbH,OU=T-Systems Trust Center,CN=T-TeleSec GlobalRoot Class 2)>
# Expires After: 2033-10-01 23:59:59
# SN: 1
# Issue: SHA1-Thumbprint 59 0d 2d 7d 88 4f 40 2e 61 7e a5 62 32 17 65 cf 17 d8 94 e9 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 590d2d7d884f402e617ea562321765cf17d894e9
# 91e2f5788d5810eba7ba58737de1548a8ecacd014598bc0b143e041b17052552
#
# Filename: E-Tugra_Certification_Authority
# Issuer: <Name(C=TR,L=Ankara,O=E-Tuğra EBG Bilişim Teknolojileri ve Hizmetleri A.Ş.,OU=E-Tugra Sertifikasyon Merkezi,CN=E-Tugra Certification Authority)>
# Subject: <Name(C=TR,L=Ankara,O=E-Tuğra EBG Bilişim Teknolojileri ve Hizmetleri A.Ş.,OU=E-Tugra Sertifikasyon Merkezi,CN=E-Tugra Certification Authority)>
# Expires After: 2023-03-03 12:09:48
# SN: 7667447206703254355
# Issue: SHA1-Thumbprint 51 c6 e7 08 49 06 6e f3 92 d4 5c a0 0d 6d a3 62 8f c3 52 39 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 51c6e70849066ef392d45ca00d6da3628fc35239
# b0bfd52bb0d7d9bd92bf5d4dc13da255c02c542f378365ea893911f55e55f23c
#
# Filename: QuoVadis_Root_CA_2
# Issuer: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 2)>
# Subject: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 2)>
# Expires After: 2031-11-24 18:23:33
# SN: 1289
# Issue: SHA1-Thumbprint ca 3a fb cf 12 40 36 4b 44 b2 16 20 88 80 48 39 19 93 7c f7 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ca3afbcf1240364b44b216208880483919937cf7
# 85a0dd7dd720adb7ff05f83d542b209dc7ff4528f7d677b18389fea5e5c49e86
#
# Filename: DigiCert_Global_Root_G2
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Global Root G2)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Global Root G2)>
# Expires After: 2038-01-15 12:00:00
# SN: 4293743540046975378534879503202253541
# Issue: SHA1-Thumbprint df 3c 24 f9 bf d6 66 76 1b 26 80 73 fe 06 d1 cc 8d 4f 82 a4 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# df3c24f9bfd666761b268073fe06d1cc8d4f82a4
# cb3ccbb76031e5e0138f8dd39a23f9de47ffc35e43c1144cea27d46a5ab1cb5f
#
# Filename: GTS_Root_R1
# Issuer: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R1)>
# Subject: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R1)>
# Expires After: 2036-06-22 00:00:00
# SN: 146587175971765017618439757810265552097
# Issue: SHA1-Thumbprint e1 c9 50 e6 ef 22 f8 4c 56 45 72 8b 92 20 60 d7 d5 a7 a3 e8 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# e1c950e6ef22f84c5645728b922060d7d5a7a3e8
# 2a575471e31340bc21581cbd2cf13e158463203ece94bcf9d3cc196bf09a5472
#
# Filename: Buypass_Class_3_Root_CA
# Issuer: <Name(C=NO,O=Buypass AS-983163327,CN=Buypass Class 3 Root CA)>
# Subject: <Name(C=NO,O=Buypass AS-983163327,CN=Buypass Class 3 Root CA)>
# Expires After: 2040-10-26 08:28:58
# SN: 2
# Issue: SHA1-Thumbprint da fa f7 fa 66 84 ec 06 8f 14 50 bd c7 c2 81 a5 bc a9 64 57 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# dafaf7fa6684ec068f1450bdc7c281a5bca96457
# edf7ebbca27a2a384d387b7d4010c666e2edb4843e4c29b4ae1d5b9332e6b24d
#
# Filename: SwissSign_Silver_CA_-_G2
# Issuer: <Name(C=CH,O=SwissSign AG,CN=SwissSign Silver CA - G2)>
# Subject: <Name(C=CH,O=SwissSign AG,CN=SwissSign Silver CA - G2)>
# Expires After: 2036-10-25 08:32:46
# SN: 5700383053117599563
# Issue: SHA1-Thumbprint 9b aa e5 9f 56 ee 21 cb 43 5a be 25 93 df a7 f0 40 d1 1d cb != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 9baae59f56ee21cb435abe2593dfa7f040d11dcb
# be6c4da2bbb9ba59b6f3939768374246c3c005993fa98f020d1dedbed48a81d5
#
# Filename: Microsoft_ECC_Root_Certificate_Authority_2017
# Issuer: <Name(C=US,O=Microsoft Corporation,CN=Microsoft ECC Root Certificate Authority 2017)>
# Subject: <Name(C=US,O=Microsoft Corporation,CN=Microsoft ECC Root Certificate Authority 2017)>
# Expires After: 2042-07-18 23:16:04
# SN: 136839042543790627607696632466672567020
# Issue: SHA1-Thumbprint 99 9a 64 c3 7f f4 7d 9f ab 95 f1 47 69 89 14 60 ee c4 c3 c5 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 999a64c37ff47d9fab95f14769891460eec4c3c5
# 358df39d764af9e1b766e9c972df352ee15cfac227af6ad1d70e8e4a6edcba02
#
# Filename: Trustwave_Global_Certification_Authority
# Issuer: <Name(C=US,ST=Illinois,L=Chicago,O=Trustwave Holdings\, Inc.,CN=Trustwave Global Certification Authority)>
# Subject: <Name(C=US,ST=Illinois,L=Chicago,O=Trustwave Holdings\, Inc.,CN=Trustwave Global Certification Authority)>
# Expires After: 2042-08-23 19:34:12
# SN: 1846098327275375458322922162
# Issue: SHA1-Thumbprint 2f 8f 36 4f e1 58 97 44 21 59 87 a5 2a 9a d0 69 95 26 7f b5 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2f8f364fe1589744215987a52a9ad06995267fb5
# 97552015f5ddfc3c8788c006944555408894450084f100867086bc1a2bb58dc8
#
# Filename: Go_Daddy_Root_Certificate_Authority_-_G2
# Issuer: <Name(C=US,ST=Arizona,L=Scottsdale,O=GoDaddy.com\, Inc.,CN=Go Daddy Root Certificate Authority - G2)>
# Subject: <Name(C=US,ST=Arizona,L=Scottsdale,O=GoDaddy.com\, Inc.,CN=Go Daddy Root Certificate Authority - G2)>
# Expires After: 2037-12-31 23:59:59
# SN: 0
# Issue: SHA1-Thumbprint 47 be ab c9 22 ea e8 0e 78 78 34 62 a7 9f 45 c2 54 fd e6 8b != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 47beabc922eae80e78783462a79f45c254fde68b
# 45140b3247eb9cc8c5b4f0d7b53091f73292089e6e5a63e2749dd3aca9198eda
#
# Filename: IdenTrust_Public_Sector_Root_CA_1
# Issuer: <Name(C=US,O=IdenTrust,CN=IdenTrust Public Sector Root CA 1)>
# Subject: <Name(C=US,O=IdenTrust,CN=IdenTrust Public Sector Root CA 1)>
# Expires After: 2034-01-16 17:53:32
# SN: 13298821034946342390521976156843933698
# Issue: SHA1-Thumbprint ba 29 41 60 77 98 3f f4 f3 ef f2 31 05 3b 2e ea 6d 4d 45 fd != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ba29416077983ff4f3eff231053b2eea6d4d45fd
# 30d0895a9a448a262091635522d1f52010b5867acae12c78ef958fd4f4389f2f
#
# Filename: NAVER_Global_Root_Certification_Authority
# Issuer: <Name(C=KR,O=NAVER BUSINESS PLATFORM Corp.,CN=NAVER Global Root Certification Authority)>
# Subject: <Name(C=KR,O=NAVER BUSINESS PLATFORM Corp.,CN=NAVER Global Root Certification Authority)>
# Expires After: 2037-08-18 23:59:59
# SN: 9013692873798656336226253319739695165984492813
# Issue: SHA1-Thumbprint 8f 6b f2 a9 27 4a da 14 a0 c4 f4 8e 61 27 f9 c0 1e 78 5d d1 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 8f6bf2a9274ada14a0c4f48e6127f9c01e785dd1
# 88f438dcf8ffd1fa8f429115ffe5f82ae1e06e0c70c375faad717b34a49e7265
#
# Filename: TeliaSonera_Root_CA_v1
# Issuer: <Name(O=TeliaSonera,CN=TeliaSonera Root CA v1)>
# Subject: <Name(O=TeliaSonera,CN=TeliaSonera Root CA v1)>
# Expires After: 2032-10-18 12:00:50
# SN: 199041966741090107964904287217786801558
# Issue: SHA1-Thumbprint 43 13 bb 96 f1 d5 86 9b c1 4e 6a 92 f6 cf f6 34 69 87 82 37 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 4313bb96f1d5869bc14e6a92f6cff63469878237
# dd6936fe21f8f077c123a1a521c12224f72255b73e03a7260693e8a24b0fa389
#
# Filename: AC_RAIZ_FNMT-RCM
# Issuer: <Name(C=ES,O=FNMT-RCM,OU=AC RAIZ FNMT-RCM)>
# Subject: <Name(C=ES,O=FNMT-RCM,OU=AC RAIZ FNMT-RCM)>
# Expires After: 2030-01-01 00:00:00
# SN: 485876308206448804701554682760554759
# Issue: SHA1-Thumbprint ec 50 35 07 b2 15 c4 95 62 19 e2 a8 9a 5b 42 99 2c 4c 2c 20 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ec503507b215c4956219e2a89a5b42992c4c2c20
# ebc5570c29018c4d67b1aa127baf12f703b4611ebc17b7dab5573894179b93fa
#
# Filename: TrustCor_RootCert_CA-1
# Issuer: <Name(C=PA,ST=Panama,L=Panama City,O=TrustCor Systems S. de R.L.,OU=TrustCor Certificate Authority,CN=TrustCor RootCert CA-1)>
# Subject: <Name(C=PA,ST=Panama,L=Panama City,O=TrustCor Systems S. de R.L.,OU=TrustCor Certificate Authority,CN=TrustCor RootCert CA-1)>
# Expires After: 2029-12-31 17:23:16
# SN: 15752444095811006489
# Issue: SHA1-Thumbprint ff bd cd e7 82 c8 43 5e 3c 6f 26 86 5c ca a8 3a 45 5b c3 0a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ffbdcde782c8435e3c6f26865ccaa83a455bc30a
# d40e9c86cd8fe468c1776959f49ea774fa548684b6c406f3909261f4dce2575c
#
# Filename: GTS_Root_R4
# Issuer: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R4)>
# Subject: <Name(C=US,O=Google Trust Services LLC,CN=GTS Root R4)>
# Expires After: 2036-06-22 00:00:00
# SN: 146587176229350439916519468929765261721
# Issue: SHA1-Thumbprint 2a 1d 60 27 d9 4a b1 0a 1c 4d 91 5c cd 33 a0 cb 3e 2d 54 cb != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2a1d6027d94ab10a1c4d915ccd33a0cb3e2d54cb
# 71cca5391f9e794b04802530b363e121da8a3043bb26662fea4dca7fc951a4bd
#
# Filename: Entrust_Root_Certification_Authority_-_G2
# Issuer: <Name(C=US,O=Entrust\, Inc.,OU=See www.entrust.net/legal-terms,OU=(c) 2009 Entrust\, Inc. - for authorized use only,CN=Entrust Root Certification Authority - G2)>
# Subject: <Name(C=US,O=Entrust\, Inc.,OU=See www.entrust.net/legal-terms,OU=(c) 2009 Entrust\, Inc. - for authorized use only,CN=Entrust Root Certification Authority - G2)>
# Expires After: 2030-12-07 17:55:54
# SN: 1246989352
# Issue: SHA1-Thumbprint 8c f4 27 fd 79 0c 3a d1 66 06 8d e8 1e 57 ef bb 93 22 72 d4 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 8cf427fd790c3ad166068de81e57efbb932272d4
# 43df5774b03e7fef5fe40d931a7bedf1bb2e6b42738c4e6d3841103d3aa7f339
#
# Filename: COMODO_ECC_Certification_Authority
# Issuer: <Name(C=GB,ST=Greater Manchester,L=Salford,O=COMODO CA Limited,CN=COMODO ECC Certification Authority)>
# Subject: <Name(C=GB,ST=Greater Manchester,L=Salford,O=COMODO CA Limited,CN=COMODO ECC Certification Authority)>
# Expires After: 2038-01-18 23:59:59
# SN: 41578283867086692638256921589707938090
# Issue: SHA1-Thumbprint 9f 74 4e 9f 2b 4d ba ec 0f 31 2c 50 b6 56 3b 8e 2d 93 c3 11 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 9f744e9f2b4dbaec0f312c50b6563b8e2d93c311
# 1793927a0614549789adce2f8f34f7f0b66d0f3ae3a3b84d21ec15dbba4fadc7
#
# Filename: Hellenic_Academic_and_Research_Institutions_RootCA_2015
# Issuer: <Name(C=GR,L=Athens,O=Hellenic Academic and Research Institutions Cert. Authority,CN=Hellenic Academic and Research Institutions RootCA 2015)>
# Subject: <Name(C=GR,L=Athens,O=Hellenic Academic and Research Institutions Cert. Authority,CN=Hellenic Academic and Research Institutions RootCA 2015)>
# Expires After: 2040-06-30 10:11:21
# SN: 0
# Issue: SHA1-Thumbprint 01 0c 06 95 a6 98 19 14 ff bf 5f c6 b0 b6 95 ea 29 e9 12 a6 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 010c0695a6981914ffbf5fc6b0b695ea29e912a6
# a040929a02ce53b4acf4f2ffc6981ce4496f755e6d45fe0b2a692bcd52523f36
#
# Filename: Certum_Trusted_Network_CA
# Issuer: <Name(C=PL,O=Unizeto Technologies S.A.,OU=Certum Certification Authority,CN=Certum Trusted Network CA)>
# Subject: <Name(C=PL,O=Unizeto Technologies S.A.,OU=Certum Certification Authority,CN=Certum Trusted Network CA)>
# Expires After: 2029-12-31 12:07:37
# SN: 279744
# Issue: SHA1-Thumbprint 07 e0 32 e0 20 b7 2c 3f 19 2f 06 28 a2 59 3a 19 a7 0f 06 9e != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 07e032e020b72c3f192f0628a2593a19a70f069e
# 5c58468d55f58e497e743982d2b50010b6d165374acf83a7d4a32db768c4408e
#
# Filename: GlobalSign_Root_CA_-_R2
# Issuer: <Name(OU=GlobalSign Root CA - R2,O=GlobalSign,CN=GlobalSign)>
# Subject: <Name(OU=GlobalSign Root CA - R2,O=GlobalSign,CN=GlobalSign)>
# Expires After: 2021-12-15 08:00:00
# SN: 4835703278459682885658125
# Issue: SHA1-Thumbprint 75 e0 ab b6 13 85 12 27 1c 04 f8 5f dd de 38 e4 b7 24 2e fe != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 75e0abb6138512271c04f85fddde38e4b7242efe
# ca42dd41745fd0b81eb902362cf9d8bf719da1bd1b1efc946f5b4c99f42c1b9e
#
# Filename: SSL.com_EV_Root_Certification_Authority_ECC
# Issuer: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com EV Root Certification Authority ECC)>
# Subject: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com EV Root Certification Authority ECC)>
# Expires After: 2041-02-12 18:15:23
# SN: 3182246526754555285
# Issue: SHA1-Thumbprint 4c dd 51 a3 d1 f5 20 32 14 b0 c6 c5 32 23 03 91 c7 46 42 6d != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 4cdd51a3d1f5203214b0c6c532230391c746426d
# 22a2c1f7bded704cc1e701b5f408c310880fe956b5de2a4a44f99c873a25a7c8
#
# Filename: Certum_Trusted_Network_CA_2
# Issuer: <Name(C=PL,O=Unizeto Technologies S.A.,OU=Certum Certification Authority,CN=Certum Trusted Network CA 2)>
# Subject: <Name(C=PL,O=Unizeto Technologies S.A.,OU=Certum Certification Authority,CN=Certum Trusted Network CA 2)>
# Expires After: 2046-10-06 08:39:56
# SN: 44979900017204383099463764357512596969
# Issue: SHA1-Thumbprint d3 dd 48 3e 2b bf 4c 05 e8 af 10 f5 fa 76 26 cf d3 dc 30 92 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d3dd483e2bbf4c05e8af10f5fa7626cfd3dc3092
# b676f2eddae8775cd36cb0f63cd1d4603961f49e6265ba013a2f0307b6d0b804
#
# Filename: UCA_Global_G2_Root
# Issuer: <Name(C=CN,O=UniTrust,CN=UCA Global G2 Root)>
# Subject: <Name(C=CN,O=UniTrust,CN=UCA Global G2 Root)>
# Expires After: 2040-12-31 00:00:00
# SN: 124779693093741543919145257850076631279
# Issue: SHA1-Thumbprint 28 f9 78 16 19 7a ff 18 25 18 aa 44 fe c1 a0 ce 5c b6 4c 8a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 28f97816197aff182518aa44fec1a0ce5cb64c8a
# 9bea11c976fe014764c1be56a6f914b5a560317abd9988393382e5161aa0493c
#
# Filename: COMODO_Certification_Authority
# Issuer: <Name(C=GB,ST=Greater Manchester,L=Salford,O=COMODO CA Limited,CN=COMODO Certification Authority)>
# Subject: <Name(C=GB,ST=Greater Manchester,L=Salford,O=COMODO CA Limited,CN=COMODO Certification Authority)>
# Expires After: 2029-12-31 23:59:59
# SN: 104350513648249232941998508985834464573
# Issue: SHA1-Thumbprint 66 31 bf 9e f7 4f 9e b6 c9 d5 a6 0c ba 6a be d1 f7 bd ef 7b != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 6631bf9ef74f9eb6c9d5a60cba6abed1f7bdef7b
# 0c2cd63df7806fa399ede809116b575bf87989f06518f9808c860503178baf66
#
# Filename: QuoVadis_Root_CA_3_G3
# Issuer: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 3 G3)>
# Subject: <Name(C=BM,O=QuoVadis Limited,CN=QuoVadis Root CA 3 G3)>
# Expires After: 2042-01-12 20:26:32
# SN: 268090761170461462463995952157327242137089239581
# Issue: SHA1-Thumbprint 48 12 bd 92 3c a8 c4 39 06 e7 30 6d 27 96 e6 a4 cf 22 2e 7d != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 4812bd923ca8c43906e7306d2796e6a4cf222e7d
# 88ef81de202eb018452e43f864725cea5fbd1fc2d9d205730709c5d8b8690f46
#
# Filename: GlobalSign_Root_CA_-_R6
# Issuer: <Name(OU=GlobalSign Root CA - R6,O=GlobalSign,CN=GlobalSign)>
# Subject: <Name(OU=GlobalSign Root CA - R6,O=GlobalSign,CN=GlobalSign)>
# Expires After: 2034-12-10 00:00:00
# SN: 1417766617973444989252670301619537
# Issue: SHA1-Thumbprint 80 94 64 0e b5 a7 a1 ca 11 9c 1f dd d5 9f 81 02 63 a7 fb d1 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 8094640eb5a7a1ca119c1fddd59f810263a7fbd1
# 2cabeafe37d06ca22aba7391c0033d25982952c453647349763a3ab5ad6ccf69
#
# Filename: Hongkong_Post_Root_CA_3
# Issuer: <Name(C=HK,ST=Hong Kong,L=Hong Kong,O=Hongkong Post,CN=Hongkong Post Root CA 3)>
# Subject: <Name(C=HK,ST=Hong Kong,L=Hong Kong,O=Hongkong Post,CN=Hongkong Post Root CA 3)>
# Expires After: 2042-06-03 02:29:46
# SN: 46170865288971385588281144162979347873371282084
# Issue: SHA1-Thumbprint 58 a2 d0 ec 20 52 81 5b c1 f3 f8 64 02 24 4e c2 8e 02 4b 02 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 58a2d0ec2052815bc1f3f86402244ec28e024b02
# 5a2fc03f0c83b090bbfa40604b0988446c7636183df9846e17101a447fb8efd6
#
# Filename: GlobalSign_ECC_Root_CA_-_R4
# Issuer: <Name(OU=GlobalSign ECC Root CA - R4,O=GlobalSign,CN=GlobalSign)>
# Subject: <Name(OU=GlobalSign ECC Root CA - R4,O=GlobalSign,CN=GlobalSign)>
# Expires After: 2038-01-19 03:14:07
# SN: 14367148294922964480859022125800977897474
# Issue: SHA1-Thumbprint 69 69 56 2e 40 80 f4 24 a1 e7 19 9f 14 ba f3 ee 58 ab 6a bb != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 6969562e4080f424a1e7199f14baf3ee58ab6abb
# bec94911c2955676db6c0a550986d76e3ba005667c442c9762b4fbb773de228c
#
# Filename: GlobalSign_Root_E46
# Issuer: <Name(C=BE,O=GlobalSign nv-sa,CN=GlobalSign Root E46)>
# Subject: <Name(C=BE,O=GlobalSign nv-sa,CN=GlobalSign Root E46)>
# Expires After: 2046-03-20 00:00:00
# SN: 1552617690338932563915843282459653771421763
# Issue: SHA1-Thumbprint 39 b4 6c d5 fe 80 06 eb e2 2f 4a bb 08 33 a0 af db b9 dd 84 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 39b46cd5fe8006ebe22f4abb0833a0afdbb9dd84
# cbb9c44d84b8043e1050ea31a69f514955d7bfd2e2c6b49301019ad61d9f5058
#
# Filename: DigiCert_High_Assurance_EV_Root_CA
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert High Assurance EV Root CA)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert High Assurance EV Root CA)>
# Expires After: 2031-11-10 00:00:00
# SN: 3553400076410547919724730734378100087
# Issue: SHA1-Thumbprint 5f b7 ee 06 33 e2 59 db ad 0c 4c 9a e6 d3 8f 1a 61 c7 dc 25 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 5fb7ee0633e259dbad0c4c9ae6d38f1a61c7dc25
# 7431e5f4c3c1ce4690774f0b61e05440883ba9a01ed00ba6abd7806ed3b118cf
#
# Filename: Entrust.net_Premium_2048_Secure_Server_CA
# Issuer: <Name(O=Entrust.net,OU=www.entrust.net/CPS_2048 incorp. by ref. (limits liab.),OU=(c) 1999 Entrust.net Limited,CN=Entrust.net Certification Authority (2048))>
# Subject: <Name(O=Entrust.net,OU=www.entrust.net/CPS_2048 incorp. by ref. (limits liab.),OU=(c) 1999 Entrust.net Limited,CN=Entrust.net Certification Authority (2048))>
# Expires After: 2029-07-24 14:15:12
# SN: 946069240
# Issue: SHA1-Thumbprint 50 30 06 09 1d 97 d4 f5 ae 39 f7 cb e7 92 7d 7d 65 2d 34 31 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 503006091d97d4f5ae39f7cbe7927d7d652d3431
# 6dc47172e01cbcb0bf62580d895fe2b8ac9ad4f873801e0c10b9c837d21eb177
#
# Filename: DigiCert_Global_Root_CA
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Global Root CA)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Global Root CA)>
# Expires After: 2031-11-10 00:00:00
# SN: 10944719598952040374951832963794454346
# Issue: SHA1-Thumbprint a8 98 5d 3a 65 e5 e5 c4 b2 d7 d6 6d 40 c6 dd 2f b1 9c 54 36 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# a8985d3a65e5e5c4b2d7d66d40c6dd2fb19c5436
# 4348a0e9444c78cb265e058d5e8944b4d84f9662bd26db257f8934a443c70161
#
# Filename: Staat_der_Nederlanden_EV_Root_CA
# Issuer: <Name(C=NL,O=Staat der Nederlanden,CN=Staat der Nederlanden EV Root CA)>
# Subject: <Name(C=NL,O=Staat der Nederlanden,CN=Staat der Nederlanden EV Root CA)>
# Expires After: 2022-12-08 11:10:28
# SN: 10000013
# Issue: SHA1-Thumbprint 76 e2 7e c1 4f db 82 c1 c0 a6 75 b5 05 be 3d 29 b4 ed db bb != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 76e27ec14fdb82c1c0a675b505be3d29b4eddbbb
# 4d2491414cfe956746ec4cefa6cf6f72e28a1329432f9d8a907ac4cb5dadc15a
#
# Filename: Hellenic_Academic_and_Research_Institutions_RootCA_2011
# Issuer: <Name(C=GR,O=Hellenic Academic and Research Institutions Cert. Authority,CN=Hellenic Academic and Research Institutions RootCA 2011)>
# Subject: <Name(C=GR,O=Hellenic Academic and Research Institutions Cert. Authority,CN=Hellenic Academic and Research Institutions RootCA 2011)>
# Expires After: 2031-12-01 13:49:52
# SN: 0
# Issue: SHA1-Thumbprint fe 45 65 9b 79 03 5b 98 a1 61 b5 51 2e ac da 58 09 48 22 4d != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# fe45659b79035b98a161b5512eacda580948224d
# bc104f15a48be709dca542a7e1d4b9df6f054527e802eaa92d595444258afe71
#
# Filename: CA_Disig_Root_R2
# Issuer: <Name(C=SK,L=Bratislava,O=Disig a.s.,CN=CA Disig Root R2)>
# Subject: <Name(C=SK,L=Bratislava,O=Disig a.s.,CN=CA Disig Root R2)>
# Expires After: 2042-07-19 09:15:30
# SN: 10572350602393338211
# Issue: SHA1-Thumbprint b5 61 eb ea a4 de e4 25 4b 69 1a 98 a5 57 47 c2 34 c7 d9 71 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b561ebeaa4dee4254b691a98a55747c234c7d971
# e23d4a036d7b70e9f595b1422079d2b91edfbb1fb651a0633eaa8a9dc5f80703
#
# Filename: Secure_Global_CA
# Issuer: <Name(C=US,O=SecureTrust Corporation,CN=Secure Global CA)>
# Subject: <Name(C=US,O=SecureTrust Corporation,CN=Secure Global CA)>
# Expires After: 2029-12-31 19:52:06
# SN: 9751836167731051554232119481456978597
# Issue: SHA1-Thumbprint 3a 44 73 5a e5 81 90 1f 24 86 61 46 1e 3b 9c c4 5f f5 3a 1b != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 3a44735ae581901f248661461e3b9cc45ff53a1b
# 4200f5043ac8590ebb527d209ed1503029fbcbd41ca1b506ec27f15ade7dac69
#
# Filename: SwissSign_Gold_CA_-_G2
# Issuer: <Name(C=CH,O=SwissSign AG,CN=SwissSign Gold CA - G2)>
# Subject: <Name(C=CH,O=SwissSign AG,CN=SwissSign Gold CA - G2)>
# Expires After: 2036-10-25 08:30:35
# SN: 13492815561806991280
# Issue: SHA1-Thumbprint d8 c5 38 8a b7 30 1b 1b 6e d4 7a e6 45 25 3a 6f 9f 1a 27 61 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d8c5388ab7301b1b6ed47ae645253a6f9f1a2761
# 62dd0be9b9f50a163ea0f8e75c053b1eca57ea55c8688f647c6881f2c8357b95
#
# Filename: Entrust_Root_Certification_Authority_-_EC1
# Issuer: <Name(C=US,O=Entrust\, Inc.,OU=See www.entrust.net/legal-terms,OU=(c) 2012 Entrust\, Inc. - for authorized use only,CN=Entrust Root Certification Authority - EC1)>
# Subject: <Name(C=US,O=Entrust\, Inc.,OU=See www.entrust.net/legal-terms,OU=(c) 2012 Entrust\, Inc. - for authorized use only,CN=Entrust Root Certification Authority - EC1)>
# Expires After: 2037-12-18 15:55:36
# SN: 51543124481930649114116133369
# Issue: SHA1-Thumbprint 20 d8 06 40 df 9b 25 f5 12 25 3a 11 ea f7 59 8a eb 14 b5 47 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 20d80640df9b25f512253a11eaf7598aeb14b547
# 02ed0eb28c14da45165c566791700d6451d7fb56f0b2ab1d3b8eb070e56edff5
#
# Filename: DigiCert_Assured_ID_Root_G3
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Assured ID Root G3)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Assured ID Root G3)>
# Expires After: 2038-01-15 12:00:00
# SN: 15459312981008553731928384953135426796
# Issue: SHA1-Thumbprint f5 17 a2 4f 9a 48 c6 c9 f8 a2 00 26 9f dc 0f 48 2c ab 30 89 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# f517a24f9a48c6c9f8a200269fdc0f482cab3089
# 7e37cb8b4c47090cab36551ba6f45db840680fba166a952db100717f43053fc2
#
# Filename: Starfield_Root_Certificate_Authority_-_G2
# Issuer: <Name(C=US,ST=Arizona,L=Scottsdale,O=Starfield Technologies\, Inc.,CN=Starfield Root Certificate Authority - G2)>
# Subject: <Name(C=US,ST=Arizona,L=Scottsdale,O=Starfield Technologies\, Inc.,CN=Starfield Root Certificate Authority - G2)>
# Expires After: 2037-12-31 23:59:59
# SN: 0
# Issue: SHA1-Thumbprint b5 1c 06 7c ee 2b 0c 3d f8 55 ab 2d 92 f4 fe 39 d4 e7 0f 0e != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b51c067cee2b0c3df855ab2d92f4fe39d4e70f0e
# 2ce1cb0bf9d2f9e102993fbe215152c3b2dd0cabde1c68e5319b839154dbb7f5
#
# Filename: USERTrust_ECC_Certification_Authority
# Issuer: <Name(C=US,ST=New Jersey,L=Jersey City,O=The USERTRUST Network,CN=USERTrust ECC Certification Authority)>
# Subject: <Name(C=US,ST=New Jersey,L=Jersey City,O=The USERTRUST Network,CN=USERTrust ECC Certification Authority)>
# Expires After: 2038-01-18 23:59:59
# SN: 123013823720199481456569720443997572134
# Issue: SHA1-Thumbprint d1 cb ca 5d b2 d5 2a 7f 69 3b 67 4d e5 f0 5a 1d 0c 95 7d f0 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d1cbca5db2d52a7f693b674de5f05a1d0c957df0
# 4ff460d54b9c86dabfbcfc5712e0400d2bed3fbc4d4fbdaa86e06adcd2a9ad7a
#
# Filename: emSign_ECC_Root_CA_-_G3
# Issuer: <Name(C=IN,OU=emSign PKI,O=eMudhra Technologies Limited,CN=emSign ECC Root CA - G3)>
# Subject: <Name(C=IN,OU=emSign PKI,O=eMudhra Technologies Limited,CN=emSign ECC Root CA - G3)>
# Expires After: 2043-02-18 18:30:00
# SN: 287880440101571086945156
# Issue: SHA1-Thumbprint 30 43 fa 4f f2 57 dc a0 c3 80 ee 2e 58 ea 78 b2 3f e6 bb c1 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 3043fa4ff257dca0c380ee2e58ea78b23fe6bbc1
# 86a1ecba089c4a8d3bbe2734c612ba341d813e043cf9e8a862cd5c57a36bbe6b
#
# Filename: DigiCert_Global_Root_G3
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Global Root G3)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Global Root G3)>
# Expires After: 2038-01-15 12:00:00
# SN: 7089244469030293291760083333884364146
# Issue: SHA1-Thumbprint 7e 04 de 89 6a 3e 66 6d 00 e6 87 d3 3f fa d9 3b e8 3d 34 9e != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 7e04de896a3e666d00e687d33ffad93be83d349e
# 31ad6648f8104138c738f39ea4320133393e3a18cc02296ef97c2ac9ef6731d0
#
# Filename: AffirmTrust_Premium
# Issuer: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Premium)>
# Subject: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Premium)>
# Expires After: 2040-12-31 14:10:36
# SN: 7893706540734352110
# Issue: SHA1-Thumbprint d8 a6 33 2c e0 03 6f b1 85 f6 63 4f 7d 6a 06 65 26 32 28 27 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d8a6332ce0036fb185f6634f7d6a066526322827
# 70a73f7f376b60074248904534b11482d5bf0e698ecc498df52577ebf2e93b9a
#
# Filename: Certum_EC-384_CA
# Issuer: <Name(C=PL,O=Asseco Data Systems S.A.,OU=Certum Certification Authority,CN=Certum EC-384 CA)>
# Subject: <Name(C=PL,O=Asseco Data Systems S.A.,OU=Certum Certification Authority,CN=Certum EC-384 CA)>
# Expires After: 2043-03-26 07:24:54
# SN: 160250656287871593594747141429395092468
# Issue: SHA1-Thumbprint f3 3e 78 3c ac df f4 a2 cc ac 67 55 69 56 d7 e5 16 3c e1 ed != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# f33e783cacdff4a2ccac67556956d7e5163ce1ed
# 6b328085625318aa50d173c98d8bda09d57e27413d114cf787a0f5d06c030cf6
#
# Filename: Starfield_Services_Root_Certificate_Authority_-_G2
# Issuer: <Name(C=US,ST=Arizona,L=Scottsdale,O=Starfield Technologies\, Inc.,CN=Starfield Services Root Certificate Authority - G2)>
# Subject: <Name(C=US,ST=Arizona,L=Scottsdale,O=Starfield Technologies\, Inc.,CN=Starfield Services Root Certificate Authority - G2)>
# Expires After: 2037-12-31 23:59:59
# SN: 0
# Issue: SHA1-Thumbprint 92 5a 8f 8d 2c 6d 04 e0 66 5f 59 6a ff 22 d8 63 e8 25 6f 3f != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 925a8f8d2c6d04e0665f596aff22d863e8256f3f
# 568d6905a2c88708a4b3025190edcfedb1974a606a13c6e5290fcb2ae63edab5
#
# Filename: Amazon_Root_CA_1
# Issuer: <Name(C=US,O=Amazon,CN=Amazon Root CA 1)>
# Subject: <Name(C=US,O=Amazon,CN=Amazon Root CA 1)>
# Expires After: 2038-01-17 00:00:00
# SN: 143266978916655856878034712317230054538369994
# Issue: SHA1-Thumbprint 8d a7 f9 65 ec 5e fc 37 91 0f 1c 6e 59 fd c1 cc 6a 6e de 16 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 8da7f965ec5efc37910f1c6e59fdc1cc6a6ede16
# 8ecde6884f3d87b1125ba31ac3fcb13d7016de7f57cc904fe1cb97c6ae98196e
#
# Filename: emSign_Root_CA_-_G1
# Issuer: <Name(C=IN,OU=emSign PKI,O=eMudhra Technologies Limited,CN=emSign Root CA - G1)>
# Subject: <Name(C=IN,OU=emSign PKI,O=eMudhra Technologies Limited,CN=emSign Root CA - G1)>
# Expires After: 2043-02-18 18:30:00
# SN: 235931866688319308814040
# Issue: SHA1-Thumbprint 8a c7 ad 8f 73 ac 4e c1 b5 75 4d a5 40 f4 fc cf 7c b5 8e 8c != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 8ac7ad8f73ac4ec1b5754da540f4fccf7cb58e8c
# 40f6af0346a99aa1cd1d555a4e9cce62c7f9634603ee406615833dc8c8d00367
#
# Filename: Autoridad_de_Certificacion_Firmaprofesional_CIF_A62634068
# Issuer: <Name(C=ES,CN=Autoridad de Certificacion Firmaprofesional CIF A62634068)>
# Subject: <Name(C=ES,CN=Autoridad de Certificacion Firmaprofesional CIF A62634068)>
# Expires After: 2030-12-31 08:38:15
# SN: 6047274297262753887
# Issue: SHA1-Thumbprint ae c5 fb 3f c8 e1 bf c4 e5 4f 03 07 5a 9a e8 00 b7 f7 b6 fa != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# aec5fb3fc8e1bfc4e54f03075a9ae800b7f7b6fa
# 04048028bf1f2864d48f9ad4d83294366a828856553f3b14303f90147f5d40ef
#
# Filename: ISRG_Root_X1
# Issuer: <Name(C=US,O=Internet Security Research Group,CN=ISRG Root X1)>
# Subject: <Name(C=US,O=Internet Security Research Group,CN=ISRG Root X1)>
# Expires After: 2035-06-04 11:04:38
# SN: 172886928669790476064670243504169061120
# Issue: SHA1-Thumbprint ca bd 2a 79 a1 07 6a 31 f2 1d 25 36 35 cb 03 9d 43 29 a5 e8 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# cabd2a79a1076a31f21d253635cb039d4329a5e8
# 96bcec06264976f37460779acf28c5a7cfe8a3c0aae11a8ffcee05c0bddf08c6
#
# Filename: Certigna_Root_CA
# Issuer: <Name(C=FR,O=Dhimyotis,OU=0002 48146308100036,CN=Certigna Root CA)>
# Subject: <Name(C=FR,O=Dhimyotis,OU=0002 48146308100036,CN=Certigna Root CA)>
# Expires After: 2033-10-01 08:32:27
# SN: 269714418870597844693661054334862075617
# Issue: SHA1-Thumbprint 2d 0d 52 14 ff 9e ad 99 24 01 74 20 47 6e 6c 85 27 27 f5 43 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 2d0d5214ff9ead9924017420476e6c852727f543
# d48d3d23eedb50a459e55197601c27774b9d7b18c94d5a059511a10250b93168
#
# Filename: certSIGN_ROOT_CA
# Issuer: <Name(C=RO,O=certSIGN,OU=certSIGN ROOT CA)>
# Subject: <Name(C=RO,O=certSIGN,OU=certSIGN ROOT CA)>
# Expires After: 2031-07-04 17:20:04
# SN: 35210227249154
# Issue: SHA1-Thumbprint fa b7 ee 36 97 26 62 fb 2d b0 2a f6 bf 03 fd e8 7c 4b 2f 9b != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ...
#
# Filename: SecureSign_RootCA11
# Issuer: <Name(C=JP,O=Japan Certification Services\, Inc.,CN=SecureSign RootCA11)>
# Subject: <Name(C=JP,O=Japan Certification Services\, Inc.,CN=SecureSign RootCA11)>
# Expires After: 2029-04-08 04:56:47
# SN: 1
# Issue: SHA1-Thumbprint 3b c4 9f 48 f8 f3 73 a0 9c 1e bd f8 5b b1 c3 65 c7 d8 11 b3 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 3bc49f48f8f373a09c1ebdf85bb1c365c7d811b3
# bf0feefb9e3a581ad5f9e9db7589985743d261085c4d314f6f5d7259aa421612
#
# Filename: DigiCert_Assured_ID_Root_CA
# Issuer: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Assured ID Root CA)>
# Subject: <Name(C=US,O=DigiCert Inc,OU=www.digicert.com,CN=DigiCert Assured ID Root CA)>
# Expires After: 2031-11-10 00:00:00
# SN: 17154717934120587862167794914071425081
# Issue: SHA1-Thumbprint 05 63 b8 63 0d 62 d7 5a bb c8 ab 1e 4b df b5 a8 99 b2 4d 43 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 0563b8630d62d75abbc8ab1e4bdfb5a899b24d43
# 3e9099b5015e8f486c00bcea9d111ee721faba355a89bcf1df69561e3dc6325c
#
# Filename: SecureTrust_CA
# Issuer: <Name(C=US,O=SecureTrust Corporation,CN=SecureTrust CA)>
# Subject: <Name(C=US,O=SecureTrust Corporation,CN=SecureTrust CA)>
# Expires After: 2029-12-31 19:40:55
# SN: 17199774589125277788362757014266862032
# Issue: SHA1-Thumbprint 87 82 c6 c3 04 35 3b cf d2 96 92 d2 59 3e 7d 44 d9 34 ff 11 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 8782c6c304353bcfd29692d2593e7d44d934ff11
# f1c1b50ae5a20dd8030ec9f6bc24823dd367b5255759b4e71b61fce9f7375d73
#
# Filename: Trustwave_Global_ECC_P384_Certification_Authority
# Issuer: <Name(C=US,ST=Illinois,L=Chicago,O=Trustwave Holdings\, Inc.,CN=Trustwave Global ECC P384 Certification Authority)>
# Subject: <Name(C=US,ST=Illinois,L=Chicago,O=Trustwave Holdings\, Inc.,CN=Trustwave Global ECC P384 Certification Authority)>
# Expires After: 2042-08-23 19:36:43
# SN: 2704997926503831671788816187
# Issue: SHA1-Thumbprint e7 f3 a3 c8 cf 6f c3 04 2e 6d 0e 67 32 c5 9e 68 95 0d 5e d2 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# e7f3a3c8cf6fc3042e6d0e6732c59e68950d5ed2
# 55903859c8c0c3ebb8759ece4e2557225ff5758bbd38ebd48276601e1bd58097
#
# Filename: SSL.com_EV_Root_Certification_Authority_RSA_R2
# Issuer: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com EV Root Certification Authority RSA R2)>
# Subject: <Name(C=US,ST=Texas,L=Houston,O=SSL Corporation,CN=SSL.com EV Root Certification Authority RSA R2)>
# Expires After: 2042-05-30 18:14:37
# SN: 6248227494352943350
# Issue: SHA1-Thumbprint 74 3a f0 52 9b d0 32 a0 f4 4a 83 cd d4 ba a9 7b 7c 2e c4 9a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 743af0529bd032a0f44a83cdd4baa97b7c2ec49a
# 2e7bf16cc22485a7bbe2aa8696750761b0ae39be3b2fe9d0cc6d4ef73491425c
#
# Filename: ACCVRAIZ1
# Issuer: <Name(CN=ACCVRAIZ1,OU=PKIACCV,O=ACCV,C=ES)>
# Subject: <Name(CN=ACCVRAIZ1,OU=PKIACCV,O=ACCV,C=ES)>
# Expires After: 2030-12-31 09:37:37
# SN: 6828503384748696800
# Issue: SHA1-Thumbprint 93 05 7a 88 15 c6 4f ce 88 2f fa 91 16 52 28 78 bc 53 64 17 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 93057a8815c64fce882ffa9116522878bc536417
# 9a6ec012e1a7da9dbe34194d478ad7c0db1822fb071df12981496ed104384113
#
# Filename: EC-ACC
# Issuer: <Name(C=ES,O=Agencia Catalana de Certificacio (NIF Q-0801176-I),OU=Serveis Publics de Certificacio,OU=Vegeu https://www.catcert.net/verarrel (c)03,OU=Jerarquia Entitats de Certificacio Catalanes,CN=EC-ACC)>
# Subject: <Name(C=ES,O=Agencia Catalana de Certificacio (NIF Q-0801176-I),OU=Serveis Publics de Certificacio,OU=Vegeu https://www.catcert.net/verarrel (c)03,OU=Jerarquia Entitats de Certificacio Catalanes,CN=EC-ACC)>
# Expires After: 2031-01-07 22:59:59
# SN: -23701579247955709139626555126524820479
# Issue: SHA1-Thumbprint 28 90 3a 63 5b 52 80 fa e6 77 4c 0b 6d a7 d6 ba a6 4a f2 e8 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 28903a635b5280fae6774c0b6da7d6baa64af2e8
# 88497f01602f3154246ae28c4d5aef10f1d87ebb76626f4ae0b7f95ba7968799
#
# Filename: AffirmTrust_Commercial
# Issuer: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Commercial)>
# Subject: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Commercial)>
# Expires After: 2030-12-31 14:06:06
# SN: 8608355977964138876
# Issue: SHA1-Thumbprint f9 b5 b6 32 45 5f 9c be ec 57 5f 80 dc e9 6e 2c c7 b2 78 b7 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# f9b5b632455f9cbeec575f80dce96e2cc7b278b7
# 0376ab1d54c5f9803ce4b2e201a0ee7eef7b57b636e8a93c9b8d4860c96f5fa7
#
# Filename: TWCA_Root_Certification_Authority
# Issuer: <Name(C=TW,O=TAIWAN-CA,OU=Root CA,CN=TWCA Root Certification Authority)>
# Subject: <Name(C=TW,O=TAIWAN-CA,OU=Root CA,CN=TWCA Root Certification Authority)>
# Expires After: 2030-12-31 15:59:59
# SN: 1
# Issue: SHA1-Thumbprint cf 9e 87 6d d3 eb fc 42 26 97 a3 b5 a3 7a a0 76 a9 06 23 48 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# cf9e876dd3ebfc422697a3b5a37aa076a9062348
# bfd88fe1101c41ae3e801bf8be56350ee9bad1a6b9bd515edc5c6d5b8711ac44
#
# Filename: Microsoft_RSA_Root_Certificate_Authority_2017
# Issuer: <Name(C=US,O=Microsoft Corporation,CN=Microsoft RSA Root Certificate Authority 2017)>
# Subject: <Name(C=US,O=Microsoft Corporation,CN=Microsoft RSA Root Certificate Authority 2017)>
# Expires After: 2042-07-18 23:00:23
# SN: 40975477897264996090493496164228220339
# Issue: SHA1-Thumbprint 73 a5 e6 4a 3b ff 83 16 ff 0e dc cc 61 8a 90 6e 4e ae 4d 74 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 73a5e64a3bff8316ff0edccc618a906e4eae4d74
# c741f70f4b2a8d88bf2e71c14122ef53ef10eba0cfa5e64cfa20f418853073e0
#
# Filename: UCA_Extended_Validation_Root
# Issuer: <Name(C=CN,O=UniTrust,CN=UCA Extended Validation Root)>
# Subject: <Name(C=CN,O=UniTrust,CN=UCA Extended Validation Root)>
# Expires After: 2038-12-31 00:00:00
# SN: 106100277556486529736699587978573607008
# Issue: SHA1-Thumbprint a3 a1 b0 6f 24 61 23 4a e3 36 a5 c2 37 fc a6 ff dd f0 d7 3a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# a3a1b06f2461234ae336a5c237fca6ffddf0d73a
# d43af9b35473755c9684fc06d7d8cb70ee5c28e773fb294eb41ee71722924d24
#
# Filename: emSign_Root_CA_-_C1
# Issuer: <Name(C=US,OU=emSign PKI,O=eMudhra Inc,CN=emSign Root CA - C1)>
# Subject: <Name(C=US,OU=emSign PKI,O=eMudhra Inc,CN=emSign Root CA - C1)>
# Expires After: 2043-02-18 18:30:00
# SN: 825510296613316004955058
# Issue: SHA1-Thumbprint e7 2e f1 df fc b2 09 28 cf 5d d4 d5 67 37 b1 51 cb 86 4f 01 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# e72ef1dffcb20928cf5dd4d56737b151cb864f01
# 125609aa301da0a249b97a8239cb6a34216f44dcac9f3954b14292f2e8c8608f
#
# Filename: Security_Communication_RootCA2
# Issuer: <Name(C=JP,O=SECOM Trust Systems CO.\,LTD.,OU=Security Communication RootCA2)>
# Subject: <Name(C=JP,O=SECOM Trust Systems CO.\,LTD.,OU=Security Communication RootCA2)>
# Expires After: 2029-05-29 05:00:39
# SN: 0
# Issue: SHA1-Thumbprint 5f 3b 8c f2 f8 10 b3 7d 78 b4 ce ec 19 19 c3 73 34 b9 c7 74 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 5f3b8cf2f810b37d78b4ceec1919c37334b9c774
# 513b2cecb810d4cde5dd85391adfc6c2dd60d87bb736d2b521484aa47a0ebef6
#
# Filename: TrustCor_ECA-1
# Issuer: <Name(C=PA,ST=Panama,L=Panama City,O=TrustCor Systems S. de R.L.,OU=TrustCor Certificate Authority,CN=TrustCor ECA-1)>
# Subject: <Name(C=PA,ST=Panama,L=Panama City,O=TrustCor Systems S. de R.L.,OU=TrustCor Certificate Authority,CN=TrustCor ECA-1)>
# Expires After: 2029-12-31 17:28:07
# SN: 9548242946988625984
# Issue: SHA1-Thumbprint 58 d1 df 95 95 67 6b 63 c0 f0 5b 1c 17 4d 8b 84 0b c8 78 bd != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 58d1df9595676b63c0f05b1c174d8b840bc878bd
# 5a885db19c01d912c5759388938cafbbdf031ab2d48e91ee15589b42971d039c
#
# Filename: Amazon_Root_CA_2
# Issuer: <Name(C=US,O=Amazon,CN=Amazon Root CA 2)>
# Subject: <Name(C=US,O=Amazon,CN=Amazon Root CA 2)>
# Expires After: 2040-05-26 00:00:00
# SN: 143266982885963551818349160658925006970653239
# Issue: SHA1-Thumbprint 5a 8c ef 45 d7 a6 98 59 76 7a 8c 8b 44 96 b5 78 cf 47 4b 1a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 5a8cef45d7a69859767a8c8b4496b578cf474b1a
# 1ba5b2aa8c65401a82960118f80bec4f62304d83cec4713a19c39c011ea46db4
#
# Filename: AffirmTrust_Networking
# Issuer: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Networking)>
# Subject: <Name(C=US,O=AffirmTrust,CN=AffirmTrust Networking)>
# Expires After: 2030-12-31 14:08:24
# SN: 8957382827206547757
# Issue: SHA1-Thumbprint 29 36 21 02 8b 20 ed 02 f5 66 c5 32 d1 d6 ed 90 9f 45 00 2f != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 293621028b20ed02f566c532d1d6ed909f45002f
# 0a81ec5a929777f145904af38d5d509f66b5e2c58fcdb531058b0e17f3f0b41b
#
# Filename: NetLock_Arany_=Class_Gold=_Főtanúsítvány
# Issuer: <Name(C=HU,L=Budapest,O=NetLock Kft.,OU=Tanúsítványkiadók (Certification Services),CN=NetLock Arany (Class Gold) Főtanúsítvány)>
# Subject: <Name(C=HU,L=Budapest,O=NetLock Kft.,OU=Tanúsítványkiadók (Certification Services),CN=NetLock Arany (Class Gold) Főtanúsítvány)>
# Expires After: 2028-12-06 15:08:21
# SN: 80544274841616
# Issue: SHA1-Thumbprint 06 08 3f 59 3f 15 a1 04 a0 69 a4 6b a9 03 d0 06 b7 97 09 91 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 06083f593f15a104a069a46ba903d006b7970991
# 6c61dac3a2def031506be036d2a6fe401994fbd13df9c8d466599274c446ec98
#
# Filename: OISTE_WISeKey_Global_Root_GB_CA
# Issuer: <Name(C=CH,O=WISeKey,OU=OISTE Foundation Endorsed,CN=OISTE WISeKey Global Root GB CA)>
# Subject: <Name(C=CH,O=WISeKey,OU=OISTE Foundation Endorsed,CN=OISTE WISeKey Global Root GB CA)>
# Expires After: 2039-12-01 15:10:31
# SN: 157768595616588414422159278966750757568
# Issue: SHA1-Thumbprint 0f f9 40 76 18 d3 d7 6a 4b 98 f0 a8 35 9e 0c fd 27 ac cc ed != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 0ff9407618d3d76a4b98f0a8359e0cfd27accced
# 6b9c08e86eb0f767cfad65cd98b62149e5494a67f5845e7bd1ed019f27b86bd6
#
# Filename: ePKI_Root_Certification_Authority
# Issuer: <Name(C=TW,O=Chunghwa Telecom Co.\, Ltd.,OU=ePKI Root Certification Authority)>
# Subject: <Name(C=TW,O=Chunghwa Telecom Co.\, Ltd.,OU=ePKI Root Certification Authority)>
# Expires After: 2034-12-20 02:31:27
# SN: 28956088682735189655030529057352760477
# Issue: SHA1-Thumbprint 67 65 0d f1 7e 8e 7e 5b 82 40 a4 f4 56 4b cf e2 3d 69 c6 f0 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 67650df17e8e7e5b8240a4f4564bcfe23d69c6f0
# c0a6f4dc63a24bfdcf54ef2a6a082a0a72de35803e2ff5ff527ae5d87206dfd5
#
# Filename: AC_RAIZ_FNMT-RCM_SERVIDORES_SEGUROS
# Issuer: <Name(C=ES,O=FNMT-RCM,OU=Ceres,2.5.4.97=VATES-Q2826004J,CN=AC RAIZ FNMT-RCM SERVIDORES SEGUROS)>
# Subject: <Name(C=ES,O=FNMT-RCM,OU=Ceres,2.5.4.97=VATES-Q2826004J,CN=AC RAIZ FNMT-RCM SERVIDORES SEGUROS)>
# Expires After: 2043-12-20 09:37:33
# SN: 131542671362353147877283741781055151509
# Issue: SHA1-Thumbprint 62 ff d9 9e c0 65 0d 03 ce 75 93 d2 ed 3f 2d 32 c9 e3 e5 4a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 62ffd99ec0650d03ce7593d2ed3f2d32c9e3e54a
# 554153b13d2cf9ddb753bfbe1a4e0ae08d0aa4187058fe60a2b862b2e4b87bcb
#
# Filename: Hongkong_Post_Root_CA_1
# Issuer: <Name(C=HK,O=Hongkong Post,CN=Hongkong Post Root CA 1)>
# Subject: <Name(C=HK,O=Hongkong Post,CN=Hongkong Post Root CA 1)>
# Expires After: 2023-05-15 04:52:29
# SN: 1000
# Issue: SHA1-Thumbprint d6 da a8 20 8d 09 d2 15 4d 24 b5 2f cb 34 6e b2 58 b2 8a 58 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# d6daa8208d09d2154d24b52fcb346eb258b28a58
# f9e67d336c51002ac054c632022d66dda2e7e3fff10ad061ed31d8bbb410cfb2
#
# Filename: D-TRUST_Root_Class_3_CA_2_EV_2009
# Issuer: <Name(C=DE,O=D-Trust GmbH,CN=D-TRUST Root Class 3 CA 2 EV 2009)>
# Subject: <Name(C=DE,O=D-Trust GmbH,CN=D-TRUST Root Class 3 CA 2 EV 2009)>
# Expires After: 2029-11-05 08:50:46
# SN: 623604
# Issue: SHA1-Thumbprint 96 c9 1b 0b 95 b4 10 98 42 fa d0 d8 22 79 fe 60 fa b9 16 83 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 96c91b0b95b4109842fad0d82279fe60fab91683
# eec5496b988ce98625b934092eec2908bed0b0f316c2d4730c84eaf1f3d34881
#
# Filename: IdenTrust_Commercial_Root_CA_1
# Issuer: <Name(C=US,O=IdenTrust,CN=IdenTrust Commercial Root CA 1)>
# Subject: <Name(C=US,O=IdenTrust,CN=IdenTrust Commercial Root CA 1)>
# Expires After: 2034-01-16 18:12:23
# SN: 13298821034946342390520003877796839426
# Issue: SHA1-Thumbprint df 71 7e aa 4a d9 4e c9 55 84 99 60 2d 48 de 5f bc f0 3a 25 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# df717eaa4ad94ec9558499602d48de5fbcf03a25
# 5d56499be4d2e08bcfcad08a3e38723d50503bde706948e42f55603019e528ae
#
# Filename: Hellenic_Academic_and_Research_Institutions_ECC_RootCA_2015
# Issuer: <Name(C=GR,L=Athens,O=Hellenic Academic and Research Institutions Cert. Authority,CN=Hellenic Academic and Research Institutions ECC RootCA 2015)>
# Subject: <Name(C=GR,L=Athens,O=Hellenic Academic and Research Institutions Cert. Authority,CN=Hellenic Academic and Research Institutions ECC RootCA 2015)>
# Expires After: 2040-06-30 10:37:12
# SN: 0
# Issue: SHA1-Thumbprint 9f f1 71 8d 92 d5 9a f3 7d 74 97 b4 bc 6f 84 68 0b ba b6 66 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 9ff1718d92d59af37d7497b4bc6f84680bbab666
# 44b545aa8a25e65a73ca15dc27fc36d24c1cb9953a066539b11582dc487b4833
#
# Filename: OISTE_WISeKey_Global_Root_GC_CA
# Issuer: <Name(C=CH,O=WISeKey,OU=OISTE Foundation Endorsed,CN=OISTE WISeKey Global Root GC CA)>
# Subject: <Name(C=CH,O=WISeKey,OU=OISTE Foundation Endorsed,CN=OISTE WISeKey Global Root GC CA)>
# Expires After: 2042-05-09 09:58:33
# SN: 44084345621038548146064804565436152554
# Issue: SHA1-Thumbprint e0 11 84 5e 34 de be 88 81 b9 9c f6 16 26 d1 96 1f c3 b9 31 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# e011845e34debe8881b99cf61626d1961fc3b931
# 8560f91c3624daba9570b5fea0dbe36ff11a8323be9486854fb3f34a5571198d
#
# Filename: Starfield_Class_2_CA
# Issuer: <Name(C=US,O=Starfield Technologies\, Inc.,OU=Starfield Class 2 Certification Authority)>
# Subject: <Name(C=US,O=Starfield Technologies\, Inc.,OU=Starfield Class 2 Certification Authority)>
# Expires After: 2034-06-29 17:39:16
# SN: 0
# Issue: SHA1-Thumbprint ad 7e 1c 28 b0 64 ef 8f 60 03 40 20 14 c3 d0 e3 37 0e b5 8a != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# ad7e1c28b064ef8f6003402014c3d0e3370eb58a
# 1465fa205397b876faa6f0a9958e5590e40fcc7faa4fb7c2c8677521fb5fb658
#
# Filename: GlobalSign_ECC_Root_CA_-_R5
# Issuer: <Name(OU=GlobalSign ECC Root CA - R5,O=GlobalSign,CN=GlobalSign)>
# Subject: <Name(OU=GlobalSign ECC Root CA - R5,O=GlobalSign,CN=GlobalSign)>
# Expires After: 2038-01-19 03:14:07
# SN: 32785792099990507226680698011560947931244
# Issue: SHA1-Thumbprint 1f 24 c6 30 cd a4 18 ef 20 69 ff ad 4f dd 5f 46 3a 1b 69 aa != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 1f24c630cda418ef2069ffad4fdd5f463a1b69aa
# 179fbc148a3dd00fd24ea13458cc43bfa7f59c8182d783a513f6ebec100c8924
#
# Filename: emSign_ECC_Root_CA_-_C3
# Issuer: <Name(C=US,OU=emSign PKI,O=eMudhra Inc,CN=emSign ECC Root CA - C3)>
# Subject: <Name(C=US,OU=emSign PKI,O=eMudhra Inc,CN=emSign ECC Root CA - C3)>
# Expires After: 2043-02-18 18:30:00
# SN: 582948710642506000014504
# Issue: SHA1-Thumbprint b6 af 43 c2 9b 81 53 7d f6 ef 6b c3 1f 1f 60 15 0c ee 48 66 != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# b6af43c29b81537df6ef6bc31f1f60150cee4866
# bc4d809b15189d78db3e1d8cf4f9726a795da1643ca5f1358e1ddb0edc0d7eb3
#
# Filename: Amazon_Root_CA_3
# Issuer: <Name(C=US,O=Amazon,CN=Amazon Root CA 3)>
# Subject: <Name(C=US,O=Amazon,CN=Amazon Root CA 3)>
# Expires After: 2040-05-26 00:00:00
# SN: 143266986699090766294700635381230934788665930
# Issue: SHA1-Thumbprint 0d 44 dd 8c 3c 8c 1a 1a 58 75 64 81 e9 0f 2e 2a ff b3 d2 6e != f3 73 b3 87 06 5a 28 84 8a f2 f3 4a ce 19 2b dd c7 8e 9c ac
# Trust By Visa
# 0d44dd8c3c8c1a1a58756481e90f2e2affb3d26e
# 18ce6cfe7bf14e60b2e347b8dfe868cb31d02ebb3ada271569f50343b46db3a4
#
# >finished
