# %%
# Importing the modules
import cv2
import numpy
from IPython.display import clear_output, display
from PIL import Image

# %%
img = cv2.imread("game.png")

# %%
r = cv2.selectROI("select the area", img)
r
# Out:
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# (563, 55, 75, 80)

# %% [raw]
# r = cv2.selectROI("select the area", img_level_1)
# r

# %% [raw]
# r = cv2.selectROI("select the area", img)
#
# r

# %% [raw]
# 17 * 3

# %% [markdown]
# everything times 3 for 2 pyrdowns!

# %%
r = (563, 55, 75, 80)

# %%
# Crop image
# cropped_image = image[int(r[1]) : int(r[1] + r[3]), int(r[0]) : int(r[0] + r[2])]

# Drawing the cross by the calculated and
# obtained coordinates
# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

img = cv2.rectangle(img, (10, 23), (100, 10), color, thickness)
img = cv2.rectangle(img, (r[0], r[1]), (r[2] + r[0], r[3] + r[2]), color, thickness)
img = cv2.rectangle(img, (10, 23), (100, 10), color, thickness)
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=1440x2880 at 0x7FDDE9D97910>
