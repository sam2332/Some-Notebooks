# %%
from Libs.Beholder import *

a = Beholder(videoFrameGenerator=pullPhoneScreen)
a.addLayerModifer(
    Beholder_Layer_Chopper_Grayscale(from_layer="image", enabled=True)
)
a.addLayerModifer(Beholder_Layer_Chopper_ColorSplit(from_layer="image", enabled=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 from Libs.Beholder import *
#       3 a = Beholder(videoFrameGenerator=pullPhoneScreen)
#       4 a.addLayerModifer(
# ----> 5     Beholder_Layer_Chopper_Grayscale(from_layer="image", enabled=True)
#       6 )
#       7 a.addLayerModifer(Beholder_Layer_Chopper_ColorSplit(from_layer="image", enabled=True))
#
# TypeError: Beholder_Layer_Chopper_Grayscale.__init__() missing 1 required positional argument: 'name'

# %%
matches = a.findMatches()

# %%
a.layers["image_R"].show()
# Out:
# <PIL.Image.Image image mode=RGB size=2400x1080 at 0x7F4F83FD1810>
